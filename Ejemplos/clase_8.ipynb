# %% [markdown]
# # Clasificación

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report
from sklearn.metrics import plot_confusion_matrix

Xt=np.load('Datos_clase8/Xtodos.npy')
Yt=np.load('Datos_clase8/Label.npy')

X_train, X_test, y_train, y_test = train_test_split(Xt, Yt, test_size=0.20)

# %%
# Model = KNeighborsClassifier(n_neighbors=5)
# Model=DecisionTreeClassifier(criterion='entropy') #el criterio puede ser gini o entropy
# Model=RandomForestClassifier(n_estimators=10) 
Model = SVC(kernel='rbf',C=2) #‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’
Model.fit(X_train, y_train) 
Yp=Model.predict(X_test)

plot_confusion_matrix(Model, X_test, y_test)
plt.show()

target_names = ['Healthy', 'Missing', 'Crack', 'Spall', 'chip5a', 'chip4a', 'chip3a', 'chip2a', 'chip1a']
print(classification_report(y_test, Yp, target_names=target_names))
# Out:
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        19
#      Missing       1.00      1.00      1.00        26
#        Crack       1.00      1.00      1.00        21
#        Spall       1.00      1.00      1.00        20
#       chip5a       1.00      1.00      1.00        22
#       chip4a       1.00      1.00      1.00        21
#       chip3a       1.00      1.00      1.00        20
#       chip2a       1.00      1.00      1.00        23
#       chip1a       1.00      1.00      1.00        16
#
#     accuracy                           1.00       188
#    macro avg       1.00      1.00      1.00       188
# weighted avg       1.00      1.00      1.00       188

# %%
# Model = KNeighborsClassifier(n_neighbors=5)
# Model=DecisionTreeClassifier(criterion='entropy') #el criterio puede ser gini o entropy
Model=RandomForestClassifier(n_estimators=10) 
Model.fit(X_train, y_train) 
Yp=Model.predict(X_test)

plot_confusion_matrix(Model, X_test, y_test)
plt.show()

target_names = ['Healthy', 'Missing', 'Crack', 'Spall', 'chip5a', 'chip4a', 'chip3a', 'chip2a', 'chip1a']
print(classification_report(y_test, Yp, target_names=target_names))
# Out:
# C:\Users\JOSELU~1\AppData\Local\Temp/ipykernel_11384/1625754978.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Model.fit(X_train, y_train)
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        19
#      Missing       1.00      1.00      1.00        26
#        Crack       1.00      1.00      1.00        21
#        Spall       1.00      1.00      1.00        20
#       chip5a       1.00      1.00      1.00        22
#       chip4a       0.95      1.00      0.98        21
#       chip3a       1.00      1.00      1.00        20
#       chip2a       1.00      0.96      0.98        23
#       chip1a       1.00      1.00      1.00        16
#
#     accuracy                           0.99       188
#    macro avg       0.99      1.00      0.99       188
# weighted avg       0.99      0.99      0.99       188

# %%
# Model = KNeighborsClassifier(n_neighbors=5)
Model=DecisionTreeClassifier(criterion='entropy') #el criterio puede ser gini o entropy
Model.fit(X_train, y_train) 
Yp=Model.predict(X_test)

plot_confusion_matrix(Model, X_test, y_test)
plt.show()

target_names = ['Healthy', 'Missing', 'Crack', 'Spall', 'chip5a', 'chip4a', 'chip3a', 'chip2a', 'chip1a']
print(classification_report(y_test, Yp, target_names=target_names))
# Out:
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        19
#      Missing       1.00      1.00      1.00        26
#        Crack       1.00      1.00      1.00        21
#        Spall       1.00      1.00      1.00        20
#       chip5a       1.00      1.00      1.00        22
#       chip4a       0.89      0.81      0.85        21
#       chip3a       1.00      1.00      1.00        20
#       chip2a       0.84      0.91      0.87        23
#       chip1a       1.00      1.00      1.00        16
#
#     accuracy                           0.97       188
#    macro avg       0.97      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188

# %%
Model = KNeighborsClassifier(n_neighbors=5)
Model.fit(X_train, y_train) 
Yp=Model.predict(X_test)

plot_confusion_matrix(Model, X_test, y_test)
plt.show()

target_names = ['Healthy', 'Missing', 'Crack', 'Spall', 'chip5a', 'chip4a', 'chip3a', 'chip2a', 'chip1a']
print(classification_report(y_test, Yp, target_names=target_names))
# Out:
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\Jose Luis\anaconda3\envs\Programacion_Cientifica\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#      Healthy       1.00      1.00      1.00        19
#      Missing       1.00      1.00      1.00        26
#        Crack       1.00      1.00      1.00        21
#        Spall       1.00      1.00      1.00        20
#       chip5a       1.00      1.00      1.00        22
#       chip4a       1.00      1.00      1.00        21
#       chip3a       1.00      1.00      1.00        20
#       chip2a       1.00      1.00      1.00        23
#       chip1a       1.00      1.00      1.00        16
#
#     accuracy                           1.00       188
#    macro avg       1.00      1.00      1.00       188
# weighted avg       1.00      1.00      1.00       188
